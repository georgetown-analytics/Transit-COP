# %%
import pandas as pd
import numpy as np

from pandas import Series, DataFrame

# %%
cars_soup = pd.read_csv('C:/Users/darog/OneDrive/Documents/CAPSTONE DATA SCIENCE/USED CARS CAPSTONE/csv files/carsoupdotcom.csv', 
                        index_col = False, error_bad_lines = False)
cars_soup.head()
# Out:
#             site    car_id  car_descrip car_make                 car_model  \
# 0  carsoupdotcom  73531922          NaN   Toyota                Corolla-LE
# 1  carsoupdotcom  72354903          NaN     Jeep  Wrangler-Unlimted-Sahara
# 2  carsoupdotcom  73704666          NaN    Honda                  Civic-LX
# 3  carsoupdotcom  73566743          NaN     Jeep    Grand-Cherokee-Limited
# 4  carsoupdotcom  73745994          NaN  Hyundai        Santa-Fe-Sport-24L
#
#    car_trim  car_year car_category  car_mileage  car_price  \
# 0        -1      2015         USED        23036      13298
# 1        -1      2012         USED        73619      26995
# 2        -1      2014         USED        27784      14097
# 3        -1      2014         USED        36636      27899
# 4        -1      2013         USED        48568      18981
#
#                      car_extColor   car_transmission car_driveTrain  \
# 0                Black Sand Pearl          Automatic            FWD
# ...

# %%
car_vendor = cars_soup['car_vendor']
car_vendor[0]
# Out:
# nan

# %%
# Using a while loop, let's fill the car_vendor colums with the car_location column - double check !! no results !!

# %%
car_location = cars_soup['car_location']
missing = np.nan

i=0
while (car_vendor[i] == missing) :
       car_vendor[i] =  car_location[i]
       i=i + 1
print car_vendor[i]
# Out:
# nan

# %%
for i in car_vendor :
    car_vendor [i] = car_location [i]
    print car_vendor[i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-9d5f3bc8c609> in <module>()
#       1 for i in car_vendor :
# ----> 2     car_vendor [i] = car_location [i]
#       3     print car_vendor[i]
#
# C:\Users\darog\Anaconda2\lib\site-packages\pandas\core\series.pyc in __getitem__(self, key)
#     601         key = com._apply_if_callable(key, self)
#     602         try:
# --> 603             result = self.index.get_value(self, key)
#     604
#     605             if not is_scalar(result):
#
# C:\Users\darog\Anaconda2\lib\site-packages\pandas\indexes\base.pyc in get_value(self, series, key)
#    2164         k = _values_from_object(key)
#    2165
# -> 2166         k = self._convert_scalar_indexer(k, kind='getitem')
#    2167         try:
#    2168             return self._engine.get_value(s, k,
#
# ...

# %%
cars_soup.isnull().sum()
# Out:
# site                    0
# car_id                  0
# car_descrip         17067
# car_make                0
# car_model               0
# car_trim                0
# car_year                0
# car_category            0
# car_mileage             0
# car_price               0
# car_extColor          357
# car_transmission      336
# car_driveTrain        336
# car_vendor          17030
# car_location           37
# car_detail_link         0
# car_img_link            0
# car_engine              0
# Unnamed: 18           337
# Unnamed: 19         17027
# dtype: int64

# %%
cars_soup.duplicated().sum()
# Out:
# 0

# %%
# no duplicated rows

# %%
# At a first glance columns car_vendor and car_location looks misplaced 
# same thing for car_detail_link and car_img_link
# Those columns must be flipped

# %%
cars_soup.isnull()
# Out:
#         site car_id car_descrip car_make car_model car_trim car_year  \
# 0      False  False        True    False     False    False    False
# 1      False  False        True    False     False    False    False
# 2      False  False        True    False     False    False    False
# 3      False  False        True    False     False    False    False
# 4      False  False        True    False     False    False    False
# 5      False  False        True    False     False    False    False
# 6      False  False        True    False     False    False    False
# 7      False  False        True    False     False    False    False
# 8      False  False        True    False     False    False    False
# 9      False  False        True    False     False    False    False
# 10     False  False        True    False     False    False    False
# 11     False  False        True    False     False    False    False
# 12     False  False        True    False     False    False    False
# ...

# %%
cars_soup.isnull().sum()
# Out:
# site                    0
# car_id                  0
# car_descrip         17067
# car_make                0
# car_model               0
# car_trim                0
# car_year                0
# car_category            0
# car_mileage             0
# car_price               0
# car_extColor          357
# car_transmission      336
# car_driveTrain        336
# car_vendor          17030
# car_location           37
# car_detail_link         0
# car_img_link            0
# car_engine              0
# Unnamed: 18           337
# Unnamed: 19         17027
# dtype: int64
