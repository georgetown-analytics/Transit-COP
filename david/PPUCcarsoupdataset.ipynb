# %%
import pandas as pd
import numpy as np

from pandas import Series, DataFrame

# %%
cars = pd.read_csv('C:/Users/darog/OneDrive/Documents/CAPSTONE DATA SCIENCE/USED CARS CAPSTONE/csv files/carsoupdotcom.csv', 
                        index_col = False, error_bad_lines = False)
cars.head(10)
# Out:
#             site    car_id  car_descrip   car_make                 car_model  \
# 0  carsoupdotcom  73531922          NaN     Toyota                Corolla-LE
# 1  carsoupdotcom  72354903          NaN       Jeep  Wrangler-Unlimted-Sahara
# 2  carsoupdotcom  73704666          NaN      Honda                  Civic-LX
# 3  carsoupdotcom  73566743          NaN       Jeep    Grand-Cherokee-Limited
# 4  carsoupdotcom  73745994          NaN    Hyundai        Santa-Fe-Sport-24L
# 5  carsoupdotcom  72021162          NaN    Hyundai                 Accent-SE
# 6  carsoupdotcom  68842989          NaN        GMC              Yukon-Denali
# 7  carsoupdotcom  72942655          NaN  Chevrolet                 Malibu-LT
# 8  carsoupdotcom  72367561          NaN    Lincoln               Navigator-L
# 9  carsoupdotcom  73099146          NaN    Hyundai            Sonata-Limited
#
#    car_trim  car_year car_category  car_mileage  car_price  \
# 0        -1      2015         USED        23036      13298
# ...

# %%
cars.isnull().sum()
# Out:
# site                    0
# car_id                  0
# car_descrip         17067
# car_make                0
# car_model               0
# car_trim                0
# car_year                0
# car_category            0
# car_mileage             0
# car_price               0
# car_extColor          357
# car_transmission      336
# car_driveTrain        336
# car_vendor          17030
# car_location           37
# car_detail_link         0
# car_img_link            0
# car_engine              0
# Unnamed: 18           337
# Unnamed: 19         17027
# dtype: int64

# %%
#Since in my previous analysis I had difficulties working with NaN values, let's fill any NaN cell with zeros

# %%
filled_cars = cars.fillna(0)
filled_cars.head()
# Out:
#             site    car_id  car_descrip car_make                 car_model  \
# 0  carsoupdotcom  73531922          0.0   Toyota                Corolla-LE
# 1  carsoupdotcom  72354903          0.0     Jeep  Wrangler-Unlimted-Sahara
# 2  carsoupdotcom  73704666          0.0    Honda                  Civic-LX
# 3  carsoupdotcom  73566743          0.0     Jeep    Grand-Cherokee-Limited
# 4  carsoupdotcom  73745994          0.0  Hyundai        Santa-Fe-Sport-24L
#
#    car_trim  car_year car_category  car_mileage  car_price  \
# 0        -1      2015         USED        23036      13298
# 1        -1      2012         USED        73619      26995
# 2        -1      2014         USED        27784      14097
# 3        -1      2014         USED        36636      27899
# 4        -1      2013         USED        48568      18981
#
#                      car_extColor   car_transmission car_driveTrain  \
# 0                Black Sand Pearl          Automatic            FWD
# ...

# %%
filled_cars.isnull().sum()
# Out:
# site                0
# car_id              0
# car_descrip         0
# car_make            0
# car_model           0
# car_trim            0
# car_year            0
# car_category        0
# car_mileage         0
# car_price           0
# car_extColor        0
# car_transmission    0
# car_driveTrain      0
# car_vendor          0
# car_location        0
# car_detail_link     0
# car_img_link        0
# car_engine          0
# Unnamed: 18         0
# Unnamed: 19         0
# dtype: int64

# %%
#there are no nulls anymore

# %%
# For any unknown reason the column car_extColor has pushed the values in the rest of columns. My assumption is that 
# the extra long color strings such as "blue deep crystal" leaves the first word (blue)in the color_extColor column but 
# pushes "deep" and "crystal" to the adjacent columns.

# The columns in the dataset are missplaced, for some cars the value expected in column car_transmission is in the 
# column car_driveTrain. The value expected in column car_driveTrain is in column car_vendor and the one expected 
# in car_vendor is in car_location and so on so forth.
# 
# We need to transfer the values from column to column using loops

# %%
car_driveTrain = filled_cars['car_driveTrain']
car_transmission = filled_cars['car_transmission']
car_location = filled_cars['car_location']
car_vendor = filled_cars['car_vendor']


for x in car_driveTrain :
     if x == 'Automatic':
          car_transmission =  x

# %%
for y in car_vendor :
     if y == 0 :
        y = car_location
else :
     car_driveTrain = y

# %%
#i=0
#while  car_vendor[i] == 0:
    #car_vendor[i] = car_location [i]
    #i = i + 1    
#else:
    #car_driveTrain [i] = car_vendor[i]
    
#car_vendor

# %%
#car_vendor[265:270]

# %%
filled_cars[425:430]
# Out:
#               site    car_id  car_descrip    car_make           car_model  \
# 425  carsoupdotcom  71863037          0.0       Mazda      MAZDA3-s-Sport
# 426  carsoupdotcom  72700644          0.0  Volkswagen  Passat-Sel-Premium
# 427  carsoupdotcom  73592588          0.0      Toyota    Tacoma-Prerunner
# 428  carsoupdotcom  73775679          0.0       Dodge          Charger-SE
# 429  carsoupdotcom  72547369          0.0       Lexus              RX-350
#
#      car_trim  car_year car_category  car_mileage  car_price  \
# 425        -1      2008         USED       103083       6499
# 426        -1      2012         USED        25730      16998
# 427        -1      2014         USED        34324      23998
# 428        -1      2016         USED        38775      16495
# 429        -1      2016         USED         9960      41887
#
#                  car_extColor   car_transmission car_driveTrain car_vendor  \
# ...

# %%
filled_cars.head()
# Out:
#             site    car_id  car_descrip car_make                 car_model  \
# 0  carsoupdotcom  73531922          0.0   Toyota                Corolla-LE
# 1  carsoupdotcom  72354903          0.0     Jeep  Wrangler-Unlimted-Sahara
# 2  carsoupdotcom  73704666          0.0    Honda                  Civic-LX
# 3  carsoupdotcom  73566743          0.0     Jeep    Grand-Cherokee-Limited
# 4  carsoupdotcom  73745994          0.0  Hyundai        Santa-Fe-Sport-24L
#
#    car_trim  car_year car_category  car_mileage  car_price  \
# 0        -1      2015         USED        23036      13298
# 1        -1      2012         USED        73619      26995
# 2        -1      2014         USED        27784      14097
# 3        -1      2014         USED        36636      27899
# 4        -1      2013         USED        48568      18981
#
#                      car_extColor   car_transmission car_driveTrain  \
# 0                Black Sand Pearl          Automatic            FWD
# ...

# %%
car_vendor[268]
# Out:
# 'AWD'

# %%
car_vendor[265:270]
# Out:
# 265      0
# 266      0
# 267      0
# 268    AWD
# 269      0
# Name: car_vendor, dtype: object

# %%
#for i in car_vendor :
 #   car_vendor [i] = car_location [i]
  #  print car_vendor[i]

# %%
cars.isnull().sum()
# Out:
# site                    0
# car_id                  0
# car_descrip         17067
# car_make                0
# car_model               0
# car_trim                0
# car_year                0
# car_category            0
# car_mileage             0
# car_price               0
# car_extColor          357
# car_transmission      336
# car_driveTrain        336
# car_vendor          17030
# car_location           37
# car_detail_link         0
# car_img_link            0
# car_engine              0
# Unnamed: 18           337
# Unnamed: 19         17027
# dtype: int64

# %%
filled_cars.duplicated().sum()
# Out:
# 0

# %%
# no duplicated rows
