# %% [markdown]
# # DATA VISUALIZATION

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
df = pd.read_csv('/home/brian/Documents/project/data/most_recent_version2.csv', 
            index_col = 0 , error_bad_lines = False)

# %%
df.head()
# Out:
#          car_make                 car_model  car_year  car_mileage  car_price  \
# car_id
# 73531922   Toyota                Corolla-LE      2015        23036      13298
# 72354903     Jeep  Wrangler-Unlimted-Sahara      2012        73619      26995
# 73704666    Honda                  Civic-LX      2014        27784      14097
# 73566743     Jeep    Grand-Cherokee-Limited      2014        36636      27899
# 73745994  Hyundai        Santa-Fe-Sport-24L      2013        48568      18981
#
#            car_transmission car_driveTrain     car_vendor car_location  \
# car_id
# 73531922          Automatic            FWD      Chantilly     VA 20151
# 72354903          AUTOMATIC            4WD      Baltimore     MD 21215
# 73704666          Automatic            FWD  Ellicott City     MD 21043
# 73566743  8-Speed Automatic            4WD        Palmyra     PA 17078
# 73745994                  A            AWD     Doylestown     PA 18902
#
#                                    car_engine
# car_id
# 73531922  1.8 4 Cylinder Sequential-Port F.I.
# 72354903                      3.6L 6 CYL. GAS
# 73704666                             1.80L I4
# 73566743            3.6L V6 Flex Fuel 24V VVT
# 73745994                             2.40L I4

# %% [markdown]
# ### Let's take first a look on what we have

# %%
df.groupby('car_make').count()
# Out:
#                car_model  car_year  car_mileage  car_price  car_transmission  \
# car_make
# Acura                513       513          513        513               510
# Alfa Romeo             1         1            1          1                 1
# Aston Martin          10        10           10         10                10
# Audi                 458       458          458        458               456
# BMW                 1048      1048         1048       1048              1042
# Bentley               15        15           15         15                15
# Buick                311       311          311        311               310
# Cadillac             431       431          431        431               414
# Chevrolet           1851      1851         1851       1851              1823
# Chrysler             452       452          452        452               451
# Dodge                707       707          707        707               704
# FIAT                  42        42           42         42                42
# Ferrari               14        14           14         14                14
# Ford                2249      2249         2249       2249              2225
# GMC                  442       442          442        442               440
# Genesis                7         7            7          7                 6
# Honda               1602      1602         1602       1602              1583
# Hummer                 9         9            9          9                 9
# Hyundai             1833      1833         1833       1833              1755
# Infiniti             257       257          257        257               255
# Isuzu                  2         2            2          2                 2
# Jaguar               122       122          122        122               111
# Jeep                1127      1127         1127       1127              1103
# Kia                  725       725          725        725               723
# Lamborghini           31        31           31         31                31
# Land Rover           171       171          171        171               150
# Lexus                518       518          518        518               515
# Lincoln              171       171          171        171               169
# MG                     1         1            1          1                 1
# MINI                 117       117          117        117               115
# Maserati              45        45           45         45                41
# Maybach                1         1            1          1                 1
# Mazda                396       396          396        396               390
# McLaren                5         5            5          5                 5
# Mercedes-Benz        739       739          739        739               738
# Mercury               40        40           40         40                40
# Mitsubishi           109       109          109        109                99
# Nissan              1342      1342         1342       1342              1323
# Oldsmobile             3         3            3          3                 3
# Pontiac               26        26           26         26                26
# Porsche              132       132          132        132               132
# Ram                  318       318          318        318               308
# Rolls-Royce            2         2            2          2                 2
# Saab                   3         3            3          3                 3
# Saturn                22        22           22         22                21
# Scion                 66        66           66         66                65
# Smart                 13        13           13         13                13
# Subaru               647       647          647        647               645
# Suzuki                10        10           10         10                10
# Tesla                  2         2            2          2                 2
# Toyota              1663      1663         1663       1663              1639
# Triumph                1         1            1          1                 1
# Volkswagen           648       648          648        648               645
# Volvo                124       124          124        124               122
#
#                car_driveTrain  car_vendor  car_location  car_engine
# car_make
# Acura                     510         513           513         334
# Alfa Romeo                  1           1             1           0
# Aston Martin               10          10            10           9
# Audi                      456         458           458         303
# BMW                      1042        1048          1048         791
# Bentley                    15          15            15          13
# Buick                     310         311           311         242
# Cadillac                  414         431           431         298
# Chevrolet                1823        1851          1851        1536
# Chrysler                  451         452           452         320
# Dodge                     704         707           707         552
# FIAT                       42          42            42          28
# Ferrari                    14          14            14          12
# Ford                     2225        2249          2249        1922
# GMC                       440         442           442         357
# Genesis                     6           7             7           6
# Honda                    1583        1602          1602        1289
# Hummer                      9           9             9           7
# Hyundai                  1755        1833          1833        1532
# Infiniti                  255         257           257         172
# Isuzu                       2           2             2           2
# Jaguar                    111         122           122          91
# Jeep                     1103        1127          1127         958
# Kia                       723         725           725         639
# Lamborghini                31          31            31          31
# Land Rover                150         171           171         123
# Lexus                     515         518           518         273
# Lincoln                   169         171           171         112
# MG                          1           1             1           0
# MINI                      115         117           117          77
# Maserati                   41          45            45          31
# Maybach                     1           1             1           1
# Mazda                     390         396           396         315
# McLaren                     5           5             5           4
# Mercedes-Benz             738         739           739         383
# Mercury                    40          40            40          34
# Mitsubishi                 99         109           109          80
# Nissan                   1323        1342          1342        1013
# Oldsmobile                  3           3             3           3
# Pontiac                    26          26            26          21
# Porsche                   132         132           132          84
# Ram                       308         318           318         277
# Rolls-Royce                 2           2             2           2
# Saab                        3           3             3           1
# Saturn                     21          22            22          20
# Scion                      65          66            66          51
# Smart                      13          13            13           9
# Subaru                    645         647           647         594
# Suzuki                     10          10            10          10
# Tesla                       2           2             2           1
# Toyota                   1639        1663          1663        1196
# Triumph                     1           1             1           0
# Volkswagen                645         648           648         483
# Volvo                     122         124           124          66

# %%
#comments

# %%
df.sort_values(by= "car_make")
# Out:
#           car_make                      car_model  car_year  car_mileage  \
# car_id
# 73601154     Acura                            TLX      2015        33748
# 703231988    Acura                            RDX      2016        16443
# 71326368     Acura  MDX-Advance-Entertainment-Pkg      2014        19872
# 72835632     Acura                       MDX-Tech      2014        29395
# 702543847    Acura                            MDX      2015        31362
# 72497794     Acura                  TLX-V6-w-Tech      2016        16101
# 73601144     Acura                            TLX      2015        18327
# 72579936     Acura                            RDX      2017        11548
# 73031316     Acura                            MDX      2014        26747
# 73750506     Acura                            ILX      2016        40127
# 700812792    Acura                            MDX      2014        31561
# 72777833     Acura                       MDX-Tech      2016        22310
# 703279945    Acura                            RDX      2016        21770
# 71224746     Acura             Tl-Special-Edition      2014        36589
# 72776275     Acura                            RDX      2014        26612
# 705337320    Acura                             TL      2013        28956
# 705809828    Acura                            RDX      2015        16993
# 700372086    Acura                             TL      2014        29046
# 73458841     Acura                             TL      2012        63610
# 73460761     Acura                   Ilx-Tech-Pkg      2014        29840
# 73024323     Acura                             TL      2014        21535
# 73680490     Acura                   Ilx-Tech-Pkg      2013        97054
# 701777812    Acura                            ILX      2014        29306
# 71886329     Acura                            TSX      2004       183519
# 73460764     Acura                   Ilx-Tech-Pkg      2014        31283
# 73750507     Acura                       RDX-Tech      2014        38725
# 704533263    Acura                            RDX      2014        52751
# 72419851     Acura                       RDX-Tech      2014        28748
# 73741129     Acura                       RDX-Tech      2014        35327
# 702543958    Acura                            MDX      2014        30540
# ...            ...                            ...       ...          ...
# 701563741    Volvo                           XC70      2016        30111
# 701562961    Volvo                           XC60      2014        64644
# 701562897    Volvo                           XC70      2016        29617
# 73618715     Volvo                 S60-T5-Dynamic      2017         8032
# 73474399     Volvo                         S60-T6      2012       104493
# 73048923     Volvo                 S60-T5-Premier      2014        15315
# 71390312     Volvo         V60-T5-Drive-E-Premier      2016        34097
# 701563041    Volvo              V60 Cross Country      2016        10122
# 73391220     Volvo                           XC60      2014        37897
# 701241002    Volvo                            V60      2016        34854
# 73747586     Volvo                        S40-24I      2008        69829
# 701777882    Volvo                            V60      2016        34588
# 700610740    Volvo                S60 Inscription      2016         6137
# 73419326     Volvo                S60-T6-R-Design      2013        48491
# 73386209     Volvo                S60-T5-Platinum      2014        31433
# 701562887    Volvo              V60 Cross Country      2016         6695
# 69231205     Volvo                         S80-T6      2015         3362
# 73057085     Volvo                           XC60      2014        57446
# 701563173    Volvo              V60 Cross Country      2016         8653
# 73074294     Volvo                         C30-T5      2011       101831
# 73314428     Volvo                         S80-T6      2013        57147
# 73551837     Volvo                 S60-T5-Premier      2014        58734
# 71111467     Volvo                        S40-24I      2005       136501
# 701562677    Volvo              V60 Cross Country      2016         9640
# 73410990     Volvo                         S60-T5      2012        43001
# 72261367     Volvo                        XC60-32      2012        83240
# 701563031    Volvo              V60 Cross Country      2016         9766
# 72972818     Volvo                        Xc60-T6      2015        17100
# 73128929     Volvo                S60-T5-Platinum      2013        45624
# 73026673     Volvo                        S40-24I      2007        47031
#
#            car_price                   car_transmission car_driveTrain  \
# car_id
# 73601154       23990                            8-Speed            FWD
# 703231988      32000                          Automatic            FWD
# 71326368       38990        6-Speed Shiftable Automatic            AWD
# 72835632       29949                                  A            FWD
# 702543847      33998                          Automatic            FWD
# 72497794       26984                          Automatic            FWD
# 73601144       24990                            8-Speed            FWD
# 72579936       33990        6-Speed Shiftable Automatic            FWD
# 73031316       32990        6-Speed Shiftable Automatic            AWD
# 73750506       19990                            8-Speed            FWD
# 700812792      33998                          Automatic            FWD
# 72777833       41990        9-Speed Shiftable Automatic            AWD
# 703279945      27997                  6-Speed Automatic            AWD
# 71224746       18800                          Automatic            FWD
# 72776275       25998                                  A            FWD
# 705337320      19750                          Automatic            FWD
# 705809828      29725                  6-Speed Automatic            AWD
# 700372086      23750                          Automatic            FWD
# 73458841       15599                                  A            FWD
# 73460761       19990        5-Speed Shiftable Automatic            FWD
# 73024323       21998                                  A            FWD
# 73680490       14990        5-Speed Shiftable Automatic            FWD
# 701777812      18000                          Automatic            FWD
# 71886329        5000                  5-Speed Automatic            FWD
# 73460764       19990        5-Speed Shiftable Automatic            FWD
# 73750507       25990        6-Speed Shiftable Automatic            AWD
# 704533263      22500                          Automatic            FWD
# 72419851       25490        6-Speed Shiftable Automatic            FWD
# 73741129       26984                          Automatic            AWD
# 702543958      35987                          Automatic            FWD
# ...              ...                                ...            ...
# 701563741      31500                          Automatic            FWD
# 701562961      24750                          Automatic            FWD
# 701562897      31250                          Automatic            FWD
# 73618715       30998                                  A            AWD
# 73474399       12899  6-Speed Automatic with Geartronic            AWD
# 73048923       23988                          Automatic            AWD
# 71390312       21999                          AUTOMATIC            FWD
# 701563041      30000                          Automatic            FWD
# 73391220       25998                                  A            AWD
# 701241002      23500                          Automatic            FWD
# 73747586       10998                          Automatic            FWD
# 701777882      23500                          Automatic            FWD
# 700610740      29250                          Automatic            FWD
# 73419326       23682                          AUTOMATIC            AWD
# 73386209       20998                                  A            FWD
# 701562887      30500                          Automatic            FWD
# 69231205       30600                          Automatic            AWD
# 73057085       24591                Shiftable Automatic            AWD
# 701563173      30250                          Automatic            FWD
# 73074294       11000                             Manual            FWD
# 73314428       21998                                  A            AWD
# 73551837       16998                                  A            FWD
# 71111467        4900                              5 Spd            FWD
# 701562677      29750                          Automatic            FWD
# 73410990       13993                          Automatic            FWD
# 72261367       16900                          Automatic            AWD
# 701563031      30000                          Automatic            FWD
# 72972818       36998                                  A            AWD
# 73128929       19598                                  A            FWD
# 73026673       11998                          Automatic            FWD
#
#                      car_vendor     car_location  \
# car_id
# 73601154           Turnersville         NJ 08012
# 703231988          Falls Church     Falls Church
# 71326368           Turnersville         NJ 08012
# 72835632           Delray Beach         FL 33483
# 702543847              Bethesda         Bethesda
# 72497794             Woodbridge         VA 22191
# 73601144           Turnersville         NJ 08012
# 72579936           Turnersville         NJ 08012
# 73031316           Turnersville         NJ 08012
# 73750506           Turnersville         NJ 08012
# 700812792              Bethesda         Bethesda
# 72777833           Turnersville         NJ 08012
# 703279945       Capitol Heights  Capitol Heights
# 71224746                Ephrata         PA 17522
# 72776275             Fort Myers         FL 33966
# 705337320            Washington       Washington
# 705809828          Falls Church     Falls Church
# 700372086            Washington       Washington
# 73458841          Boynton Beach         FL 33426
# 73460761           Turnersville         NJ 08012
# 73024323         Fredericksburg         VA 22407
# 73680490           Turnersville         NJ 08012
# 701777812            Washington       Washington
# 71886329           Turnersville         NJ 08012
# 73460764           Turnersville         NJ 08012
# 73750507           Turnersville         NJ 08012
# 704533263            Washington       Washington
# 72419851           Turnersville         NJ 08012
# 73741129             Woodbridge         VA 22191
# 702543958              Bethesda         Bethesda
# ...                         ...              ...
# 701563741            Washington       Washington
# 701562961            Washington       Washington
# 701562897            Washington       Washington
# 73618715             Midlothian         VA 23114
# 73474399                Palmyra         PA 17078
# 73048923              Allentown         PA 18103
# 71390312             Lake Worth         FL 33461
# 701563041            Washington       Washington
# 73391220          Boynton Beach         FL 33426
# 701241002            Washington       Washington
# 73747586              Frederick         MD 21704
# 701777882            Washington       Washington
# 700610740            Washington       Washington
# 73419326             Fort Myers         FL 33908
# 73386209        King Of Prussia         PA 19406
# 701562887            Washington       Washington
# 69231205              Lake Park         FL 33403
# 73057085                Fairfax         VA 22030
# 701563173            Washington       Washington
# 73074294   Cape May Court House         NJ 08210
# 73314428        King Of Prussia         PA 19406
# 73551837             Brandywine         MD 20613
# 71111467           Philadelphia         PA 19124
# 701562677            Washington       Washington
# 73410990        West Palm Beach         FL 33413
# 72261367                Ephrata         PA 17522
# 701563031            Washington       Washington
# 72972818        King Of Prussia         PA 19406
# 73128929           Gaithersburg         MD 20877
# 73026673                 Laurel         MD 20723
#
#                                       car_engine
# car_id
# 73601154         2.4 4 Cylinder Direct Injection
# 703231988                                    NaN
# 71326368            3.5 6 Cylinder Fuel Injected
# 72835632                                3.50L V6
# 702543847                                    NaN
# 72497794                                 V6 3.5L
# 73601144         2.4 4 Cylinder Direct Injection
# 72579936            3.5 6 Cylinder Fuel Injected
# 73031316            3.5 6 Cylinder Fuel Injected
# 73750506            2.4 4 Cylinder Fuel Injected
# 700812792                                    NaN
# 72777833            3.5 6 Cylinder Fuel Injected
# 703279945                                    NaN
# 71224746                         6 Cylinder 3.5L
# 72776275                                3.50L V6
# 705337320                                    NaN
# 705809828                                    NaN
# 700372086                                    NaN
# 73458841                                3.50L V6
# 73460761            2.0 4 Cylinder Fuel Injected
# 73024323                                3.50L V6
# 73680490            2.0 4 Cylinder Fuel Injected
# 701777812                                    NaN
# 71886329            2.4 4 Cylinder Fuel Injected
# 73460764            2.0 4 Cylinder Fuel Injected
# 73750507            3.5 6 Cylinder Fuel Injected
# 704533263                                    NaN
# 72419851            3.5 6 Cylinder Fuel Injected
# 73741129                                 V6 3.5L
# 702543958                                    NaN
# ...                                          ...
# 701563741                                    NaN
# 701562961                                    NaN
# 701562897                                    NaN
# 73618715                                2.00L I4
# 73474399   3.0L 6-Cylinder MPI Turbocharged DOHC
# 73048923                                    2.5L
# 71390312                                   2.0 L
# 701563041                                    NaN
# 73391220                                3.00L I6
# 701241002                                    NaN
# 73747586                                2.40L I5
# 701777882                                    NaN
# 700610740                                    NaN
# 73419326                                    3.0L
# 73386209                                2.50L I5
# 701562887                                    NaN
# 69231205             3.0 6 Cylinder Turbocharged
# 73057085      3.0 6 Cylinder Fuel Injected Turbo
# 701563173                                    NaN
# 73074294                                2.50L I5
# 73314428                                3.00L I6
# 73551837                                2.50L I5
# 71111467                        2.4L L5 DOHC 20V
# 701562677                                    NaN
# 73410990      2.5 5 Cylinder Fuel Injected Turbo
# 72261367                         6 Cylinder 3.2L
# 701563031                                    NaN
# 72972818                                3.00L I6
# 73128929                                2.50L I5
# 73026673                                2.40L I5
#
# [21594 rows x 10 columns]

# %% [markdown]
# ### Let's see if the prices make sense and there is no odd value

# %%
df.sort_values(by='car_price', ascending = False).head(10)
# Out:
#                 car_make                 car_model  car_year  car_mileage  \
# car_id
# 72525212         Ferrari           488-Spider-Base      2016          832
# 66915115     Lamborghini  Aventador-LP-700-4-Coupe      2014        15716
# 73421237     Lamborghini     Gallardo-Superleggera      2008         7634
# 61426979     Rolls-Royce                    Wraith      2014         5539
# 61790926         Ferrari                458-Spider      2012         5594
# 62095216         Ferrari                458-Ilalia      2014          535
# 71553159     Lamborghini          Huracan-LP-610-4      2015        13173
# 630396741  Mercedes-Benz                   unknown      2015           70
# 67900563         Porsche                911-GT3-RS      2016          914
# 73731957         Ferrari           599-GTB-Fiorano      2011         5443
#
#            car_price             car_transmission car_driveTrain  \
# car_id
# 72525212      387995           Dual Shift Gearbox            RWD
# 66915115      349977  7 Speed Shiftable Automatic            AWD
# 73421237      325977                         AUTO            AWD
# 61426979      289977                         AUTO            AWD
# 61790926      269977                         AUTO            RWD
# 62095216      269977                         AUTO            RWD
# 71553159      259977                         AUTO            AWD
# 630396741     249000                    Automatic            FWD
# 67900563      247977                         AUTO            RWD
# 73731957      239991               6-Speed Manual            RWD
#
#                 car_vendor car_location                            car_engine
# car_id
# 72525212   West Palm Beach     FL 33409             3.9 8 Cylinder Twin Turbo
# 66915115       North Wales     PA 19454                    12 Cylinder Engine
# 73421237       North Wales     PA 19454                    10 Cylinder Engine
# 61426979       North Wales     PA 19454                    12 Cylinder Engine
# 61790926       North Wales     PA 19454                     8 Cylinder Engine
# 62095216       North Wales     PA 19454                     8 Cylinder Engine
# 71553159       North Wales     PA 19454                    10 Cylinder Engine
# 630396741        Arlington    Arlington                                   NaN
# 67900563       North Wales     PA 19454                Flat 6 Cylinder Engine
# 73731957   West Palm Beach     FL 33409  6.0 12 Cylinder Sequential-Port F.I.

# %%
df.sort_values(by='car_price', ascending = True).head(10)
# Out:
#           car_make       car_model  car_year  car_mileage  car_price  \
# car_id
# 666297728    Honda          Accord      2000       220000        500
# 704156158  Pontiac         Sunfire      2005       168781        700
# 64202173    Nissan      Maxima-GXE      2000       287944        999
# 62154576       GMC   S-15-Jimmy-SL      1999       179683        999
# 70367747     Honda       Accord-LX      1996       263377        999
# 72657189     Buick  Lesabre-Custom      1997       113339       1200
# 703511971      BMW             528      1999       122292       1250
# 72391717      Ford       Focus-ZTS      2003       202453       1321
# 72574393    Suzuki         Forenza      2007       143177       1499
# 68486271       GMC          Safari      1996       174751       1500
#
#             car_transmission car_driveTrain    car_vendor  car_location  \
# car_id
# 666297728          Automatic            FWD   Bladensburg   Bladensburg
# 704156158          Automatic            FWD  Temple Hills  Temple Hills
# 64202173   4-Speed Automatic            FWD          Bear      DE 19701
# 62154576   4-Speed Automatic            4WD          Bear      DE 19701
# 70367747      5-Speed Manual            FWD  Somers Point      NJ 08244
# 72657189   4-Speed Automatic            FWD          Bear      DE 19701
# 703511971          Automatic            FWD   Hyattsville   Hyattsville
# 72391717   4-Speed Automatic            FWD  Turnersville      NJ 08012
# 72574393           Automatic            FWD  Philadelphia      PA 19124
# 68486271   4-Speed Automatic            RWD          Bear      DE 19701
#
#                                     car_engine
# car_id
# 666297728                                  NaN
# 704156158                                  NaN
# 64202173                  3.0 6 Cylinder Other
# 62154576                  4.3 6 Cylinder Other
# 70367747                  2.2 4 Cylinder Other
# 72657189         3.8 6 Cylinder Fuel Injection
# 703511971                                  NaN
# 72391717   2.0 4 Cylinder Sequential-Port F.I.
# 72574393                      2.0L L4 DOHC 16V
# 68486271                  4.3 6 Cylinder Other

# %% [markdown]
# ### At a first glance looks like the most expensive cars are in agreement with luxury car makes and low mileages, low prices instead are matching "normal" car makes and usually high number of miles, that behaviour was something that we already expect, let's dig a little bit in the relation between price and miles

# %%
print (df.dtypes)
# Out:
# car_make            object
# car_model           object
# car_year             int64
# car_mileage          int64
# car_price            int64
# car_transmission    object
# car_driveTrain      object
# car_vendor          object
# car_location        object
# car_engine          object
# dtype: object

# %% [markdown]
# ### We still have the issue of the negative values for the mileage, instead of dropping all the negative counts we are  gonna try to scrape it again

# %%
df.sort_values(by='car_mileage', ascending = True).head(10)
# Out:
#             car_make        car_model  car_year  car_mileage  car_price  \
# car_id
# 73799055         Kia          Niro-LX      2017           -1      26225
# 73798945         Kia         Forte-LX      2017           -1      17474
# 73799002         Kia  Optima-SX-Turbo      2017           -1      34299
# 73799009         Kia       Sorento-LX      2017           -1      27653
# 60657684  Volkswagen         Golf-GLS      2002           -1       3995
# 73672489   Chevrolet        Malibu-LT      2014           -1      14599
# 73799019         Kia       Sorento-LX      2017           -1      29593
# 73771800    Chrysler              300      2006           -1       9495
# 72629779   Chevrolet   C1500-Cheyenne      1996           -1       1995
# 72065470        Ford        Escape-SE      2017           -1      22995
#
#                                      car_transmission car_driveTrain  \
# car_id
# 73799055                                            A            FWD
# 73798945                                            M            FWD
# 73799002                                            A            FWD
# 73799009                                            A            FWD
# 60657684                            4-Speed Automatic            FWD
# 73672489  6-Speed Automatic Electronic with Overdrive            FWD
# 73799019                                            A            FWD
# 73771800                                Not Specified            RWD
# 72629779                            4-Speed Automatic            RWD
# 72065470                          Shiftable Automatic            AWD
#
#                car_vendor car_location                     car_engine
# car_id
# 73799055        Bradenton     FL 34207                       1.60L I4
# 73798945        Bradenton     FL 34207                       2.00L I4
# 73799002        Bradenton     FL 34207                       2.00L I4
# 73799009        Bradenton     FL 34207                       2.40L I4
# 60657684       Norristown     PA 19401           2.0 4 Cylinder Other
# 73672489       Alexandria     VA 22303   2.5 4 Cylinder Fuel Injected
# 73799019        Bradenton     FL 34207                       2.40L I4
# 73771800       Wilmington     DE 19808   2.7 6 Cylinder Fuel Injected
# 72629779  West Palm Beach     FL 33405  5.0 8 Cylinder Fuel Injection
# 72065470          Manheim     PA 17545    1.5 4 Cylinder Turbocharged

# %%
print (df.dtypes)
# Out:
# car_make            object
# car_model           object
# car_year             int64
# car_mileage          int64
# car_price            int64
# car_transmission    object
# car_driveTrain      object
# car_vendor          object
# car_location        object
# car_engine          object
# dtype: object

# %%
# Let's rule out the basics to define a "used car", cars showing miles under 100 from 2016 and/or 2017 should be
# considered as new cars. This assumption must be taken into account when considering outliers. We have 237 values under
# 100 miles (including the -1 ones which will be fixed shortly)

#print 'Vehicles with fewer than 100 miles:', df[df.car_mileage >= 0 < 100].count()
print 'Vehicles under 100 miles:', df[df.car_mileage < 100].count()
# Out:
# Vehicles under 100 miles: car_make            237
# car_model           237
# car_year            237
# car_mileage         237
# car_price           237
# car_transmission    220
# car_driveTrain      220
# car_vendor          237
# car_location        237
# car_engine          197
# dtype: int64

# %%
df[df.car_mileage < 100].head(10)
# Out:
#           car_make             car_model  car_year  car_mileage  car_price  \
# car_id
# 73799050       Kia       Cadenza-Premium      2017           -1      35597
# 69922246  Maserati           Ghibli-Base      2017           29      71999
# 73641005      Jeep     Cherokee-Latitude      2014           -1      16995
# 73799037       Kia                Rio-Lx      2017           -1      16622
# 73799022       Kia            Sorento-EX      2017           -1      31930
# 73799004       Kia       Optima-SX-Turbo      2017           -1      32558
# 73799033       Kia         Sorento-SX-V6      2017           -1      38786
# 73799057       Kia               Niro-FE      2017           10      24455
# 73799011       Kia            Sorento-LX      2017           -1      32358
# 73641027    Subaru  Forester-25i-Touring      2015           -1      26995
#
#          car_transmission car_driveTrain  car_vendor car_location car_engine
# car_id
# 73799050                A            FWD   Bradenton     FL 34207   3.30L V6
# 69922246              NaN            NaN    Sarasota     FL 34233        NaN
# 73641005                A            FWD  Fort Myers     FL 33966   3.20L V6
# 73799037                A            FWD   Bradenton     FL 34207   1.60L I4
# 73799022                A            FWD   Bradenton     FL 34207   2.00L I4
# 73799004                A            FWD   Bradenton     FL 34207   2.00L I4
# 73799033                A            FWD   Bradenton     FL 34207   3.30L V6
# 73799057                A            FWD   Bradenton     FL 34207   1.60L I4
# 73799011                A            FWD   Bradenton     FL 34207   2.40L I4
# 73641027        Automatic            AWD  Fort Myers     FL 33966   2.50L H4

# %% [markdown]
# #######################################################################################################################

# %% [markdown]
# ### What's the volume of our analysis? How many car makes are we gonna handle? How old are the cars, what's our year range?

# %%
print 'Number of unique years is %s' % len(df.car_year.unique())
print 'Number of unique makes is %s' % len(df.car_make.unique())
print 'Number of unique models is %s' % len(df.car_model.unique())
# Out:
# Number of unique years is 37
# Number of unique makes is 54
# Number of unique models is 2350

# %% [markdown]
# ### How many counts per year?    What'sthe most "popular" selling year?

# %%
from numpy.random import randn
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sb

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 20, 9
sb.set_style('whitegrid')

# %% [markdown]
# ## CARS MODEL PER YEAR

# %% [markdown]
# ### Number of counts vs model year. We are trying to find out what the year is from the majority of our cars come from.

# %%
fig = plt.figure()
ax = fig.gca()

plt.title('CARS MODEL PER YEAR', fontsize = 23)
plt.xticks (sorted(df.car_year.unique()), horizontalalignment='right')
plt.ylabel ('Number of counts', fontsize = 18)
plt.xlabel ('Car year', fontsize = 18)
sb.distplot(df.car_year, kde=False, hist_kws={"alpha":1 ,"linewidth":3, "width":0.8, "color": "gold"})
plt.xlim(1993, 2017)
plt.show()

#.distplot(a, bins=None, hist=True, kde=True, rug=False, fit=None, hist_kws=None, kde_kws=None, rug_kws=None, 
          #fit_kws=None, color=None, vertical=False, norm_hist=False, axlabel=None, label=None, ax=None

# %% [markdown]
# ### The majority of the cars come from years 2013 to 2016

# %% [markdown]
# ### Let's take a look on how the different features behave between them

# %%
sb.pairplot(df)

# %%
#comments

# %% [markdown]
# ## MILEAGE vs CAR MAKE

# %% [markdown]
# ### Let's take a look now to the miles distribution per car make to have an idea in what range each car make is taking up . The maximum mileage needed to be reduced at $360,000 since there was a Jeep at 1,200,000 miles messing up the plot

# %%
fig = plt.figure(figsize=(20, 15))
ax = fig.gca()
sb.boxplot(x='car_mileage', y='car_make',data=df,
            order=sorted(df.car_make.unique()),notch=True,orient='h')
plt.xlabel('Mileage',fontsize=14,fontweight="bold")
plt.ylabel('Car Make',fontsize=14,fontweight="bold")
plt.title('Mileage vs Make',fontsize=18,fontweight="bold")
plt.xlim(0,360000)
plt.show()

# In the plot below we can clearly see the outliers per car make

# %% [markdown]
# ### Mileage over all counts

# %%
# look at miles overall distribution
fig = plt.figure(figsize=(8,5))
ax = fig.gca()
sb.distplot(df.car_mileage,kde=False)
plt.xlabel('car_mileage',fontsize=14,fontweight="bold")
plt.axvline(df.car_mileage.mean(),lw=3,ls='dashed',
            color='black',label='Mean miles:'+'{0:.0f}'.format(np.mean(df.car_mileage)))
plt.title('Miles Distribution over all Listings',fontsize=18,fontweight="bold")
plt.legend(loc='upper right',fontsize=16)
plt.xlim(-1000,250000)
plt.show()

# %% [markdown]
# ## PRICE vs CAR MAKE

# %%
fig = plt.figure(figsize=(18,11))
ax = fig.gca()
sb.boxplot(x='car_price',y='car_make',data=df[df.car_price < 150000],
            order=sorted(df.car_make.unique()),notch=True,orient='h')
plt.xlabel('Price',fontsize=14,fontweight="bold")
plt.ylabel('Car Make',fontsize=14,fontweight="bold")
plt.title('Price vs Make',fontsize=18,fontweight="bold")
plt.show()

# %%
# look at price distribution
fig = plt.figure(figsize=(14,8))
ax = fig.gca()
sb.distplot(df.car_price,kde=False,bins=300)
plt.xlabel('Price',fontsize=14,fontweight="bold")
plt.axvline(df.car_price.mean(),lw=3,ls='dashed',
            color='black',label='Mean price:'+'{0:.0s}'.format(np.mean(df)))
plt.title('Distribution of Prices over all Listings',fontsize=18,fontweight="bold")
plt.legend(loc='upper right',fontsize=16)
plt.xlim(-1000,150000)
plt.show()

# %%
#cars_df = pd.DataFrame((df.ix[:, (3,5)].values), columns = ['car_year', 'car_price'])
#cars_target = df.ix[:,1].values
#target_names = ['Toyota', 'Chevrolet', 'Ford'] 

#cars_df['group'] = pd.Series(cars_target, dtype="category")
#sb.pairplot(cars_df, hue='group', palette='hls')
