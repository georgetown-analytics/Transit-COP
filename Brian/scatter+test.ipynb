# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('/home/brian/Documents/project/data/Transit-COP/Brian/most_recent_version2.csv', 
            index_col = 0 , error_bad_lines = False)

# %%
#df = df.groupby('car_mileage').filter(lambda x: len(x) < 300000)
#df[df['car_mileage'] < 300000]
#df.filter('car_mileage') < 300000
#df

# %%
dfgroup = df.groupby('car_make').filter(lambda x: len(x) > 200)
dfgroup.car_make.value_counts()
# Out:
# Ford             2249
# Chevrolet        1851
# Hyundai          1833
# Toyota           1663
# Honda            1602
# Nissan           1342
# Jeep             1127
# BMW              1048
# Mercedes-Benz     739
# Kia               725
# Dodge             707
# Volkswagen        648
# Subaru            647
# Lexus             518
# Acura             513
# Audi              458
# Chrysler          452
# GMC               442
# Cadillac          431
# Mazda             396
# Ram               318
# Buick             311
# Infiniti          257
# Name: car_make, dtype: int64

# %%
sns.lmplot(x='car_mileage', y='car_price', data=dfgroup)

# %%
sns.lmplot(x='car_price', y='car_mileage', data=dfgroup)

# %%
sns.lmplot(x='car_year', y='car_price', data=dfgroup)

# %%
# Plot using Seaborn
sns.lmplot(x='car_mileage', y='car_price', data=dfgroup,
           fit_reg=False,
           hue='car_make')

# %%
sns.lmplot(x='car_mileage', y='car_price', data=dfgroup,
           fit_reg=False,
           hue='car_year')

# %%
# Plot using Seaborn
sns.lmplot(x='car_mileage', y='car_price', data=dfgroup,
           fit_reg=False,
           hue='car_make')
# Tweak using Matplotlib
plt.ylim(0, None)
plt.xlim(0, None)
# Out:
# (0, 1402968.9578986941)

# %%
sns.boxplot(data=dfgroup)
