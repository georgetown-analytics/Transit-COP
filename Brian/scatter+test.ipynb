# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('/home/brian/Documents/project/data/most_recent_version2.csv', 
            index_col = 0 , error_bad_lines = False)

# %%
#df.head()

# %%
sns.lmplot(x='car_mileage', y='car_price', data=df)

# %%
sns.lmplot(x='car_price', y='car_mileage', data=df)

# %%
sns.lmplot(x='car_year', y='car_price', data=df)

# %%
# Plot using Seaborn
sns.lmplot(x='car_mileage', y='car_price', data=df,
           fit_reg=False,
           hue='car_make')

# %%
sns.lmplot(x='car_mileage', y='car_price', data=df,
           fit_reg=False,
           hue='car_year')

# %%
# Plot using Seaborn
sns.lmplot(x='car_mileage', y='car_price', data=df,
           fit_reg=False,
           hue='car_make')
# Tweak using Matplotlib
plt.ylim(0, None)
plt.xlim(0, None)
# Out:
# (0, 1402789.6186231726)

# %%
sns.boxplot(data=df)
